# %%
import glob
import os

# %%
root_dir = '/scratch3/users/liutianyang/katcali_pipeline/'
level = 'level2/'
src = 'logs/BOX13_20251015_090000/'

# %%
logs_dir = os.path.join(root_dir, level, src)

i = 0
bad = []
for f in glob.glob(logs_dir + "job_*.out"):
    if not i % 100:
        print(i)
    with open(f, "r", encoding="utf-8", errors="ignore") as fp:
        lines = fp.read().rstrip().splitlines()
        if not lines or lines[-1] != "Hakuna Matata":
            bad.append(f)
    i += 1

print("未正常结束的任务：")
for x in bad:
    print(x)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 未正常结束的任务：
# /scratch3/users/liutianyang/katcali_pipeline/level2/logs/BOX13_20251015_090000/job_1750887085_m010h_11763946.out
# /scratch3/users/liutianyang/katcali_pipeline/level2/logs/BOX13_20251015_090000/job_1753129121_m024v_11769648.out
# /scratch3/users/liutianyang/katcali_pipeline/level2/logs/BOX13_20251015_090000/job_1750887085_m016h_11763816.out
# /scratch3/users/liutianyang/katcali_pipeline/level2/logs/BOX13_20251015_090000/job_1750887085_m009v_11763801.out
# /scratch3/users/liutianyang/katcali_pipeline/level2/logs/BOX13_20251015_090000/job_1750887085_m041h_11764008.out
# /scratch3/users/liutianyang/katcali_pipeline/level2/logs/BOX13_20251015_090000/job_1750887085_m017h_11763818.out
# /scratch3/users/liutianyang/katcali_pipeline/level2/logs/BOX13_20251015_090000/job_1753129121_m037v_11769701.out
# ...

# %%
bad
# Out:
# ['/scratch3/users/liutianyang/katcali_pipeline/level2/logs/desi1_20251109_160000/job_1678295187_m045h_11915903.out',
#  '/scratch3/users/liutianyang/katcali_pipeline/level2/logs/desi1_20251109_160000/job_1678122565_m059h_11916129.out',
#  '/scratch3/users/liutianyang/katcali_pipeline/level2/logs/desi1_20251109_160000/job_1677174749_m050h_11916007.out',
#  '/scratch3/users/liutianyang/katcali_pipeline/level2/logs/desi1_20251109_160000/job_1678743988_m037v_11915798.out',
#  '/scratch3/users/liutianyang/katcali_pipeline/level2/logs/desi1_20251109_160000/job_1684087370_m024v_11915554.out',
#  '/scratch3/users/liutianyang/katcali_pipeline/level2/logs/desi1_20251109_160000/job_1678743988_m042h_11915871.out',
#  '/scratch3/users/liutianyang/katcali_pipeline/level2/logs/desi1_20251109_160000/job_1678743988_m062v_11916141.out',
#  '/scratch3/users/liutianyang/katcali_pipeline/level2/logs/desi1_20251109_160000/job_1678295187_m048v_11915938.out',
# ...
